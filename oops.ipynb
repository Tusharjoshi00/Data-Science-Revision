# %%
## oop
# / class / object / polymorphism / encapsulation/ inheritance / abstraction
#  a  CLASS  is blueprint of object (yeh batata hai object kesa behave krega)
# class has  data or property and function or behaviour


# OBJECT ---- instance of class 
# syntax of object --objectname =classname()
#for example s=str()

# Pascal case ---> HelloWorld (both first letter is capital)

# #creating atm class
# class atm:
#     #constructor # special function --- superpower --> const. k ander jo likha hhua h usko call krne ki jrurat nahi wo apne aap ho jata run object se
#     def __init__(self):
#         self.pin =''
#         self.balance = 0
#         self.menu()
#     def menu(self):
#        uder_input= input("""
#       hi how can we help you?
#       1. press 1 for create pin
#       2. press 2 for  change pin
#       3. press 4to check balance
#       4 press 4  for withdraw
#       5. anything else
#        """)
#       if user_input =='1':
#       elif user_input =='2':
#       elif user_input =='3':
#       elif user_input =='4':
#       else:    
#          exit()
# obj=atm()



## methods  vs  function
# class k ander jo function banate hai usko method bulate hai
# or jo bahar hota h class ka wo function kehelta hai


#class k ander jo bhi cheeze hoti hai usko sirf object access kr sakta hai


# class fraction :
#     #parameterized constructor
#     def __init__(self,x,y):
#         self.num = x
#         self.den = y
#     def __str__(self):
#         return '{}/{}'.format(self.num,self.den)
#     def __add__(self,other):
#         new_num=self.num*other.den + other.num*self.den
#         new_den = self.den*other.den

#         return '{}/{}'.format(new_num,new_den)
#     def __sub__(self,other):
#         new_num=self.num*other.den - other.num*self.den
#         new_den = self.den*other.den

#         return '{}/{}'.format(new_num,new_den)
#     def __mul__(self,other):
#         new_num=self.num*other.num 
#         new_den = self.den*other.den

#         return '{}/{}'.format(new_num,new_den)
  
  
# fr1=fraction(3,4)
# fr2=fraction(1,2)

# print(fr1+fr2)
# print(fr1-fr2)
# print(fr1*fr2)



# class point :
#     def __init__(self,x,y):
#         self.x_cod =x
#         self.y_cod = y
#     def __str__(self):
#          return '<{},{}>'.format(self.x_cod,self.y_cod) 
#     def euc(self,other):
#         return ((self.x_cod - other.x_cod)**2 +(self.y_cod - other.y_cod)**2)**0.5 #sq root k liye 0.5
#     def distance_from_origin(self):
#         return self.euc(point(0,0))
# class line :
#     def __init__(self,a,b,c):
#         self.a=a
#         self.b=b
#         self.c=c
#     def __str__(self):
#         return '{}x + {}y + c = 0'.format(self.a,self.b,self.c)
#     def line_on_point(line,point):
#         if line.a*point.x_cod + line.b*point.y_cod + line.c ==0:
#             return"yes"
#         else:
#             return "no"
#     def shotest_distance(line,point):
#         return abs(line.a*point.x_cod + line.b*point.y_cod +line.c) / (line.a**2 + line.b**2)**0.5
# l1 =line(1,1,-2)
# p1=point(1,1)
# print(l1)
# print(p1)
# l1.shotest_distance(p1)
# # l1.line_on_point(p1)
# # p1 = point(0,0)
# # p2 = point(10,10)
# # p1.distance_from_origin()


#reference variable
#object without reference 
class person :
    def __init__(self):
        self.name = "jo"
        self.country ='india'
# person() # here we are no usigng reference which is p = person()
p=person()
q=p

#cahnge attribute value with the help of 2nd object
print(p.name)
print(q.name)
q.name="ankit"
print(q.name)
print(p.name)
# Out:
# jo
# jo
# ankit
# ankit

# %%
# #encapsulation
# class person :
#     def __init__(self,name_input,country_input):
#         self.name = name_input
#         self.country = country_input
# p1=person("jo","ind")
# p2=person("o","aus")
# # .name and . country is instance variable

## getter and setter
#pehele value set krte hai fir wo get m  milti hai
# but likhte pheele get h fir set hai
 

#static variable (vs instance variable)
# instance variable ogject ka variable hota h or sbke liye alag hota hai
# static variable object k liye same hota h or static var class ka hota ha
# class atm:

#     #static variable 
#     counter =1
#     def __init__(self):
#         blah blah

    #static variable
    # atm.counter #----class ka naam dot static variable ka naam

#utility method
# @staticmethod
# def get_counter():
#     return.__counter

# %%
# class relationship
# 1. aggregation --> has a relationship --> one class owns the other class
# like customer class owns a address---customer owns a address
# class customer :
#     def __init__(self,name, address, gender):
#         self.name =name
#         self.gender = gender
#         self.address =address
#     def print_add(self):
#         print(self.address.city, self.address.state,self.address.pin)

# class address :
#     def __init__(self,city,state,pin):
#         self.city =city
#         self.state =state
#         self.pin = pin
# add1=address('gurugram','haryana',302011)
# cust=customer('jo',add1,'male')
# cust.print_add()



# 2. inheritance
class user :
    def __init__(self):
        self.name ='jo'
    def login(self):
        print('login')
#child
class  student(user):
    # def __init__(self):
    #    self.roll_no =100
    
    def enroll(self):
        print('enrolll into course')
u = user()
s= student()
print(s.name)
# print(s.roll_no)


# IN CLASS DIAGRAM FOR AGGREGATION THERE WILL BE RHOMBUS (kajukatli)
# for inheritance there will be arrow -> // arrow ka head parent ki trf hota hai



# what get inherit?
#1.constructor
#2.no private attribute
#3.non private method


#child class never acces parent private member/attribute of class
#by getter we can access private class member too
# Out:
# jo

# %%
## in method overriding --parent me or child me ek function same naam  se hota hai
# us time child ka suna jata h
# in simple jab baat choice ki aaye toh baccho ki suni jati hai

# %%
#super keyword
#super ko use krke parent ko access kr sakte hai
# super always use in class or mostly in child class // class k bahar error dega

# %%
#inheritance summary
# a class can inherit from another class
#inherit improves the   ocde reuse
# constructor , method , attribute  get inherit fclato child class
#the parent has no acess to the child clASS
#private property not directly access
#child class k be ovverride --> method overriding
#super()

# %%
#polymorphism ka mtlb hota h situation k hisab se dhang se behave kre
#1. method overloading
#2.method overrriding -> dono ka same hai toh child ka call hoga
#3.operator overloading

# %%
# Out:
# 6
